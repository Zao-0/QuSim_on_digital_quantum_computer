# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
ed_df = pd.read_csv('data/ed_local_mag_long.csv')
trotter_df = pd.read_csv('data/tro_local_mag_long.csv')
qiskit_df = pd.read_csv('data/qiskit_local_mag_long.csv')

# %%
ticks = [0.1*i for i in range(101)]
color_list = ['#66FFFF','#3FEB76','#EB613F']
plt.plot(ticks, ed_df.Z6, color=color_list[0],label='Ref')
plt.plot(ticks,trotter_df.Z6,color=color_list[1],label='Trotter')
plt.plot(ticks,qiskit_df.Z6,color=color_list[2],label='qiskit')
plt.xlabel('Time')
plt.ylabel('⟨Pz_6⟩')
plt.title('Local Magnetism Long term')
plt.legend()
plt.show()

# %%
ed_df = pd.read_csv('data/ed_local_mag.csv')
trotter_df = pd.read_csv('data/tro_local_mag.csv')
qiskit_df = pd.read_csv('data/qiskit_local_mag.csv')

# %%
ticks = [0.01*i for i in range(251)]
plt.plot(ticks, ed_df.Z6, color=color_list[0],label='Ref')
plt.plot(ticks,trotter_df.Z6,color=color_list[1],label='Trotter')
plt.plot(ticks,qiskit_df.Z6,color=color_list[2],label='qiskit')
plt.xlabel('Time')
plt.ylabel('⟨Pz_6⟩')
plt.title('Local Magnetism Boundary')
plt.legend()
plt.show()

# %%
plt.plot(ticks, ed_df.Z4, color=color_list[0],label='Ref')
plt.plot(ticks,trotter_df.Z4,color=color_list[1],label='Trotter')
plt.plot(ticks,qiskit_df.Z4,color=color_list[2],label='qiskit')
plt.xlabel('Time')
plt.ylabel('⟨Pz_4⟩')
plt.title('Local Magnetism Center')
plt.legend()
plt.show()
